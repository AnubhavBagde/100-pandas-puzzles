# %% [markdown]
# <a href="https://colab.research.google.com/github/AnubhavBagde/100-pandas-puzzles/blob/master/Sign_Language_Generation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/ultralytics/yolov5.git
# %cd yolov5
# Out:
# Cloning into 'yolov5'...
# remote: Enumerating objects: 17581, done.
# remote: Counting objects: 100% (63/63), done.
# remote: Compressing objects: 100% (54/54), done.
# remote: Total 17581 (delta 39), reused 9 (delta 9), pack-reused 17518 (from 4)
# Receiving objects: 100% (17581/17581), 16.66 MiB | 11.85 MiB/s, done.
# Resolving deltas: 100% (12043/12043), done.
# /content/yolov5

# %%
# !pip install requirements.txt
import torch
from IPython.display import Image, clear_output #display images
print(f'Setup complete. Using torch {torch.__version__} ({torch.cuda.get_device_properties(0).name if torch.cuda.is_available() else "CPU"}')
# Out:
# ERROR: Could not find a version that satisfies the requirement requirements.txt (from versions: none)
# HINT: You are attempting to install a package literally named "requirements.txt" (which cannot exist). Consider using the '-r' flag to install the packages listed in requirements.txt
# ERROR: No matching distribution found for requirements.txt
# Setup complete. Using torch 2.8.0+cu126 (Tesla T4

# %%
import zipfile
import os

zip_path = "/content/spliting.zip"

# Unzip into /content/dataset
with zipfile.ZipFile(zip_path, 'r') as zip_ref:
    zip_ref.extractall("/content/dataset")

# Check contents
os.listdir("/content/dataset")
# Out:
# ['spliting']

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !ls "/content/drive/MyDrive"
# Out:
# 'Colab Notebooks'   Jovian   spliting

# %%
# !ls "/content/drive/MyDrive/spliting"
# Out:
# test  train  validation

# %%
# %%writefile /content/drive/MyDrive/spliting/data.yaml
# test: /content/drive/MyDrive/spliting/test/images
# train: /content/drive/MyDrive/spliting/train/images
# val: /content/drive/MyDrive/spliting/validation/images
#
# nc: 23
#
# names: [
#   "again",
# "bathroom",
# "eat_food",
# "father",
# "fine",
# "finish","go_to","hello","help","learn","like","me","milk","more","mother","no","please","see you later","sign","thank you",
# "want","what","yes"
# ]
# Out:
# Writing /content/drive/MyDrive/spliting/data.yaml

# %%
# %cd yolov5
# !pip install -r requirements.txt
# Out:
# [Errno 2] No such file or directory: 'yolov5'
# /content/yolov5
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 72.4 MB/s eta 0:00:00
# ...

# %%
# !python train.py --img 640 --batch 8 --epochs 150 --data /content/drive/MyDrive/spliting/data.yaml --weights yolov5s.pt --cache
# Out:
# Streaming output truncated to the last 5000 lines.
#     110/149       2.3G    0.02604    0.01275    0.00823         18        640:  92% 56/61 [00:09<00:00,  6.19it/s]/content/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#     110/149       2.3G    0.02584    0.01264   0.008106         12        640:  93% 57/61 [00:09<00:00,  6.49it/s]/content/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#     110/149       2.3G     0.0257     0.0126   0.008044         22        640:  95% 58/61 [00:09<00:00,  7.06it/s]/content/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
# ...

# %%
# !python val.py --weights /content/yolov5/runs/train/exp/weights/best.pt --data /content/drive/MyDrive/spliting/data.yaml --img 640 --iou 0.5 --task val
# Out:
# val: data=/content/drive/MyDrive/spliting/data.yaml, weights=['/content/yolov5/runs/train/exp/weights/best.pt'], batch_size=32, imgsz=640, conf_thres=0.001, iou_thres=0.5, max_det=300, task=val, device=, workers=8, single_cls=False, augment=False, verbose=False, save_txt=False, save_hybrid=False, save_conf=False, save_json=False, project=runs/val, name=exp, exist_ok=False, half=False, dnn=False
# YOLOv5 🚀 v7.0-430-g459d8bf0 Python-3.12.11 torch-2.8.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
#
# Fusing layers...
# Model summary: 157 layers, 7072156 parameters, 0 gradients, 15.9 GFLOPs
# val: Scanning /content/drive/MyDrive/spliting/validation/labels.cache... 138 images, 3 backgrounds, 0 corrupt: 100% 138/138 [00:00<?, ?it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 5/5 [00:03<00:00,  1.34it/s]
#                    all        138        142      0.899      0.893       0.94      0.628
# ...

# %%
# !python detect.py \
  --weights /content/yolov5/runs/train/exp/weights/best.pt \
  --source /content/drive/MyDrive/spliting/test/images \
  --img 640 \
  --conf 0.25 \
  --save-txt --save-conf
# Out:
# detect: weights=['/content/yolov5/runs/train/exp/weights/best.pt'], source=/content/drive/MyDrive/spliting/test/images, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=True, save_format=0, save_csv=False, save_conf=True, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 v7.0-430-g459d8bf0 Python-3.12.11 torch-2.8.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
#
# Fusing layers...
# Model summary: 157 layers, 7072156 parameters, 0 gradients, 15.9 GFLOPs
# image 1/69 /content/drive/MyDrive/spliting/test/images/e3206019-thank_you.42f88d58-95f4-11f0-b5cb-14d4243e0d19.jpg: 480x640 1 thank you, 52.7ms
# ...

# %%
# !cp /content/yolov5/runs/train/exp/weights/best.pt /content/drive/MyDrive/spliting/
